# %% [markdown]
# <a href="https://colab.research.google.com/github/senjuti238/Machine-Learning-practice/blob/main/K_means_Day14_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import the dataset

data = pd.read_csv("/content/Mall_Customers.csv")

# get independent variables for clustering

x = data.iloc[:, [3,4]].values

# 3rd column - Annual inc, 4th column - Spending score

# %%
# we need to find number of optimal clusters

from sklearn.cluster import KMeans

lst = [] # to handle the data which is being forwarded to the cluster

# give the range of th cluster, and the loop must be repeated until we complete processing the cluster

for i in range(1,11):
  kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
  kmeans.fit(x)
  lst.append(kmeans.inertia_) # To get distance value from centroid to new data point

plt.plot(range(1,11), lst)
plt.title("K-Means Clustering")
plt.xlabel("Number of Clusters ")
plt.ylabel("number of Entries")
plt.show()

# %%
# now we need to give specific count of no. of clusters

kmeans = KMeans(n_clusters= 5, init = "k-means++")

y_kmeans = kmeans.fit_predict(x)

# %%
# create 5 different clusters and visualoze

# 0 for female, 1 for male

plt.scatter(x[y_kmeans == 0,0], x[y_kmeans == 0,1], s = 10, c = 'red', label = "Cluster1")
plt.scatter(x[y_kmeans == 1,0], x[y_kmeans == 1,1], s = 10, c = 'orange', label = "Cluster2")
plt.scatter(x[y_kmeans == 2,0], x[y_kmeans == 2,1], s = 10, c = 'yellow', label = "Cluster3")
plt.scatter(x[y_kmeans == 3,0], x[y_kmeans == 3,1], s = 10, c = 'green', label = "Cluster4")
plt.scatter(x[y_kmeans == 4,0], x[y_kmeans == 4,1], s = 10, c = 'blue', label = "Cluster5")

# create centroid

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c = "black", label = "Centroid")

plt.title("K-Means final cluster")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")

plt.legend()
plt.show()

# %%
# now we need to give specific count of no. of clusters

kmeans = KMeans(n_clusters= 10, init = "k-means++")

y_kmeans = kmeans.fit_predict(x)

# %%
# create 10 different clusters and visualize

# 0 for female, 1 for male

plt.scatter(x[y_kmeans == 0,0], x[y_kmeans == 0,1], s = 10, c = 'red', label = "Cluster1")
plt.scatter(x[y_kmeans == 1,0], x[y_kmeans == 1,1], s = 10, c = 'orange', label = "Cluster2")
plt.scatter(x[y_kmeans == 2,0], x[y_kmeans == 2,1], s = 10, c = 'yellow', label = "Cluster3")
plt.scatter(x[y_kmeans == 3,0], x[y_kmeans == 3,1], s = 10, c = 'green', label = "Cluster4")
plt.scatter(x[y_kmeans == 4,0], x[y_kmeans == 4,1], s = 10, c = 'blue', label = "Cluster5")
plt.scatter(x[y_kmeans == 5,0], x[y_kmeans == 5,1], s = 10, c = 'pink', label = "Cluster6")
plt.scatter(x[y_kmeans == 6,0], x[y_kmeans == 6,1], s = 10, c = 'brown', label = "Cluster7")
plt.scatter(x[y_kmeans == 7,0], x[y_kmeans == 7,1], s = 10, c = 'purple', label = "Cluster8")
plt.scatter(x[y_kmeans == 8,0], x[y_kmeans == 8,1], s = 10, c = 'gray', label = "Cluster9")
plt.scatter(x[y_kmeans == 9,0], x[y_kmeans == 9,1], s = 10, c = 'olive', label = "Cluster10")

# create centroid

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c = "black", label = "Centroid")

plt.title("K-Means final cluster")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")

plt.legend()
plt.show()
